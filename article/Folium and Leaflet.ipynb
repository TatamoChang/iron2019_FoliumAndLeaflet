# %%
import folium
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## Vector Layers

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
road = folium.vector_layers.PolyLine(
    locations=[
    [22.73264868398435, 120.28450012207031],
    [22.72837380478485, 120.28450012207031],
    [22.723307108275556, 120.28604507446288]
]).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
nuk_range = folium.vector_layers.Polygon([
    [
        [22.72979877936457, 120.27806282043456],
        [22.732134122265894, 120.28162479400635],
        [22.73252993914425, 120.29046535491942],
        [22.73684426881351, 120.29025077819824],
        [22.737715034437908, 120.28591632843016],
        [22.735617271475324, 120.28505802154541],
        [22.73767545430257, 120.2777624130249],
        [22.733717382905326, 120.27643203735352],
        [22.733638220308723, 120.27523040771484],
        [22.72979877936457, 120.27806282043456]
    ], 
    [
        [22.731461230943435, 120.27870655059813],
        [22.732292449154702, 120.28007984161376],
        [22.733163243766654, 120.27900695800781],
        [22.73264868398435, 120.27767658233643],
        [22.731461230943435, 120.27870655059813]
    ]
], fill = True).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fillup = folium.vector_layers.path_options(fill=True)

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.Rectangle([
    [22.727344647244575, 120.27111053466797],
    [22.739219071089853, 120.29419898986816]
], fill = True).add_to(myMap);
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.Circle([22.73444963475145, 120.28458595275877], radius=50, fill = True).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.CircleMarker([22.73444963475145, 120.28458595275877], radius=50, fill = True).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Raster Layers

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=6)
imageUrl = 'https://opendata.cwb.gov.tw/fileapi/opendata/MSC/O-B0028-003.jpg'
imageBounds = [[18.600625745, 115.976888855], [27.79937425, 126.02300114]];
folium.raster_layers.ImageOverlay(imageUrl, imageBounds, opacity = 0.4).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=6)
folium.raster_layers.TileLayer(tiles = "https://{s}.tile.openstreetmap.fr/hot/{z}/{x}/{y}.png",
                               attr = '&copy; <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a>, Tiles courtesy of <a href="http://hot.openstreetmap.org/" target="_blank">Humanitarian OpenStreetMap Team</a>',
).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=6)
videoUrl = 'https://www.mapbox.com/bites/00188/patricia_nasa.webm'
videoBounds = [[ 32, -130], [ 13, -100]]
folium.raster_layers.VideoOverlay(videoUrl, videoBounds).add_to(myMap)
myMap.fit_bounds(videoBounds)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=6)
folium.WmsTileLayer("http://mesonet.agron.iastate.edu/cgi-bin/wms/nexrad/n0r.cgi",
    layers= 'nexrad-n0r-900913',
    format= 'image/png',
    transparent= True,
    attribution= "Weather data © 2012 IEM Nexrad"
).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Extra Features

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.ClickForMarker().add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.ClickForMarker("I love Tatamo~~").add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.ColorLine([
    [22.73264868398435, 120.28450012207031],[22.72837380478485, 120.28450012207031],[22.723307108275556, 120.28604507446288],
    [22.727502979677855, 120.27437210083008],[22.732094540515035, 120.28209686279295],[22.732569520769065, 120.29059410095213],
    [22.73241119420103, 120.29239654541016],[22.721644557594896, 120.29093742370605]
],
    [0, 1, 2, 3, 4, 5, 6],
    colormap = ['red', 'blue', 'green', 'orange'],
    weight = 5
).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## CustomIcon

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
myIcon = folium.CustomIcon('https://raw.githubusercontent.com/HanInfinity/iron2018_FoliumAndLeaflet/master/dist/icon/marker.png',
                          icon_size = (30, 30),
                          icon_anchor = (15, 30))
folium.Marker([22.73444963475145, 120.28458595275877], icon = myIcon).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## DivIcon
#
# > 尚未能測試成功

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)

div = folium.DivIcon()

folium.Marker([22.73444963475145, 120.28458595275877], icon = div).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## GeoJson

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.GeoJson('KaoMetropolitanPark.json').add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.TopoJson('KaoMetropolitanPark_topo.json', 'objects').add_to(myMap)
myMap
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/folium/folium.py in _repr_html_(self, **kwargs)
#     286             self._parent = None
#     287         else:
# --> 288             out = self._parent._repr_html_(**kwargs)
#     289         return out
#     290
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/branca/element.py in _repr_html_(self, **kwargs)
#     317
#     318         """
# ...

# %% [markdown]
# ## GeoJsonTooltip

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
kaoParkTooltip = folium.GeoJsonTooltip(['Name', 'type'])
folium.GeoJson('KaoMetropolitanPark.json', tooltip=kaoParkTooltip).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## RegularPolygonMarker

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
folium.RegularPolygonMarker([22.73444963475145, 120.28458595275877], number_of_sides=5, fill_color='red', color='blue').add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Vega

# %%
import json
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
veagdata = folium.Vega(json.load(open('vegaData.json')), width=450, height=250)
folium.Marker([22.73444963475145, 120.28458595275877], popup=folium.Popup(max_width=450).add_child(veagdata)).add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 27. Folium_建立高雄市區界地圖

# %%
myMap = folium.Map([22.73444963475145, 120.28458595275877], zoom_start=14)
kaoDistrict = folium.GeoJson('../dist/mapdata/KaoDistrictRange.json').add_to(myMap)
myMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
import pandas as pd
import ssl
import json

# %%
park_url = "https://data.kcg.gov.tw/api/action/datastore_search?resource_id=fe3f93da-9673-4f7b-859c-9017d793f798" 

# 因為open data平台的ssl憑證為自行建立，所以會有讀取ssl憑證錯誤的問題，所以在讀取前需要先關閉驗證程序
ssl._create_default_https_context = ssl._create_unverified_context
parking = pd.read_json(park_url)

# %%
parking
# Out:
#                                                           help  success  \
# _links       https://data.kcg.gov.tw/api/3/action/help_show...     True
# fields       https://data.kcg.gov.tw/api/3/action/help_show...     True
# records      https://data.kcg.gov.tw/api/3/action/help_show...     True
# resource_id  https://data.kcg.gov.tw/api/3/action/help_show...     True
# total        https://data.kcg.gov.tw/api/3/action/help_show...     True
#
#                                                         result
# _links       {'start': '/api/action/datastore_search?resour...
# fields       [{'type': 'int4', 'id': '_id'}, {'type': 'nume...
# records      [{'停車場名稱': '財稅大樓', '座標-經度': '120.309858', '編號'...
# resource_id               fe3f93da-9673-4f7b-859c-9017d793f798
# total                                                      243

# %%
data = json.dumps(parking.loc['records']['result'])
data
# Out:
# '[{"\\u505c\\u8eca\\u5834\\u540d\\u7a31": "\\u8ca1\\u7a05\\u5927\\u6a13", "\\u5ea7\\u6a19-\\u7d93\\u5ea6": "120.309858", "\\u7de8\\u865f": "1", "\\u71df\\u696d\\u6642\\u9593": "24\\u5c0f\\u6642", "\\u8173\\u8e0f\\u8eca": null, "\\u578b\\u5f0f": "\\u5730\\u4e0b", "\\u884c\\u653f\\u5340": "\\u65b0\\u8208\\u5340", "\\u6536\\u8cbb\\u6a19\\u6e96(\\u6536\\u8cbb\\u6642\\u9593)": "\\u8a08\\u664230\\u5143/\\u6708\\u7968\\uff1a\\u4e00\\u822c\\u6c11\\u773e\\u5168\\u65e52700\\u5143\\u3001\\u4e00\\u822c\\u6c11\\u773e\\u591c\\u95931800\\u5143", "\\u90f5\\u905e\\u5340\\u865f": "800", "\\u5927\\u578b\\u8eca": null, "\\u6a5f\\u8eca": null, "\\u5c0f\\u578b\\u8eca": "126", "_id": 1, "\\u5099  \\u8a3b": "\\u670d\\u52d9\\u96fb\\u8a71\\uff1a(07)229-1941", "\\u505c\\u8eca\\u5834\\u4f4d\\u7f6e": "\\u4e2d\\u6b63\\u4e09\\u8def25\\u865f", "\\u5ea7\\u6a19-\\u7def\\u5ea6": "22.630674"}, {"\\u505c\\u8eca\\u5834\\u540d\\u7a31": "\\u5fe0\\u5b5d", "\\u5ea7\\u6a19-\\u7d93\\u5ea6": "120.306056", "\\u7de8\\u865f": "2",
# ...

# %%
pd.read_json(data)
# Out:
#     _id              停車場位置          停車場名稱  \
# 0     1            中正三路25號           財稅大樓
# 1     2           忠孝一路331號             忠孝
# 2     3           民權一路221號          民權輕鋼架
# 3     4          中正三路、錦田路口           錦田機車
# 4     5            文武一街65號             自強
# 5     6           新田路268號旁             新田
# 6     7          成功一路、前金二街           成功機車
# 7     8          六合二路與瑞源路口           六合夜市
# 8     9          生興一巷、中正四路           林投機車
# 9    10          自強三路、光明街口           自強三路
# 10   11            五福一路67號           文化中心
# 11   12           凱旋二路130號             凱旋
# 12   13           苓雅一路226號             四維
# 13   14            輔仁路123號             武廟
# 14   15            允文街、永明街             允文
# 15   16          三多一路、輔仁路口             金馬
# 16   17         福德三路、三多一路口             福裕
# 17   18         苓雅一路、文橫二路口             苓中
# 18   19       英明路、英明路163巷口             英明
# 19   20            輔仁路、明德路             輔仁
# 20   21         建國一路與福德二路口             福德
# ...
